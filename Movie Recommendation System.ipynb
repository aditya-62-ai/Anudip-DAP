# %%
import pandas as pd
import numpy as np
# Load the dataset
df = pd.read_csv('data.csv')
df.head()
# Out:
#           id             title          type                  genres  \
# 0  tt0903747      Breaking Bad      tvSeries  Crime, Drama, Thriller
# 1  tt5491994   Planet Earth II  tvMiniSeries             Documentary
# 2  tt0185906  Band of Brothers  tvMiniSeries     Drama, History, War
# 3  tt0795176      Planet Earth  tvMiniSeries     Documentary, Family
# 4  tt5152226      Tree of Life      tvSeries                   Drama
#
#    averageRating  numVotes  releaseYear
# 0            9.5   2220756         2008
# 1            9.5    161283         2016
# 2            9.4    542837         2001
# 3            9.4    222817         2006
# 4            9.4     11445         2014

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6030    False
# 6031    False
# 6032    False
# 6033    False
# 6034    False
# Length: 6035, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6035 entries, 0 to 6034
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             6035 non-null   object
#  1   title          6035 non-null   object
#  2   type           6035 non-null   object
#  3   genres         6035 non-null   object
#  4   averageRating  6035 non-null   float64
#  5   numVotes       6035 non-null   int64
#  6   releaseYear    6035 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 330.2+ KB

# %%
cat_col = [col for col in df.columns if df[col].dtype == 'object']
print('Categorical columns :',cat_col)
# Numerical columns
num_col = [col for col in df.columns if df[col].dtype != 'object']
print('Numerical columns :',num_col)
# Out:
# Categorical columns : ['id', 'title', 'type', 'genres']
# Numerical columns : ['averageRating', 'numVotes', 'releaseYear']

# %%
#Droping the Null Value
df1 = df.drop(columns=['title','type'])
df1.shape
# Out:
# (6035, 5)

# %%
# Checking for Null Value
round((df1.isnull().sum()/df1.shape[0])*100,2)
# Out:
# id               0.0
# genres           0.0
# averageRating    0.0
# numVotes         0.0
# releaseYear      0.0
# dtype: float64

# %%
#Scatter Plot
import pandas as pd
import matplotlib.pyplot as plt
# reading the database
data = pd.read_csv("data.csv")
# Scatter plot with day against tip
plt.scatter(data['title'] , data['type'])
# Adding Title to the Plot
plt.title("Scatter Plot")
# Setting the X and Y labels
plt.xlabel('title')
plt.ylabel('type')
plt.show()

# %%
print(df.columns)  # To check available columns
print(df.index)    # To check index values
# Out:
# Index(['id', 'title', 'type', 'genres', 'averageRating', 'numVotes',
#        'releaseYear'],
#       dtype='object')
# RangeIndex(start=0, stop=6035, step=1)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Reading the database
data = pd.read_csv("data.csv")

# Ensure the correct columns exist
print(data.columns)  # Optional: To verify column names

# Scatter plot with 'numVotes' on the x-axis and 'averageRating' on the y-axis
plt.scatter(data['numVotes'], data['averageRating'],
            c=data['releaseYear'], s=data['numVotes']*0.01, alpha=0.5)

# Adding title to the plot
plt.title("Scatter Plot of Average Rating vs Number of Votes")

# Setting the correct X and Y labels
plt.xlabel('Number of Votes')
plt.ylabel('Average Rating')

# Adding a colorbar to represent 'releaseYear'
plt.colorbar(label='Release Year')

# Display the plot
plt.show()
# Out:
# Index(['id', 'title', 'type', 'genres', 'averageRating', 'numVotes',
#        'releaseYear'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Reading the database
data = pd.read_csv("data.csv")

# Line plot using 'averageRating' and 'numVotes'
plt.plot(data['averageRating'], label='Average Rating')
plt.plot(data['numVotes'], label='Number of Votes')

# Adding title to the plot
plt.title("Average Rating and Number of Votes Over Data Points")

# Setting the X and Y labels
plt.xlabel('Index')
plt.ylabel('Values')

# Adding a legend to distinguish the two plots
plt.legend()

# Display the plot
plt.show()

# %%
# Bar Chart
import pandas as pd
import matplotlib.pyplot as plt

# Reading the database
data = pd.read_csv("data.csv")

# Bar chart with 'numVotes' on x-axis and 'averageRating' on y-axis
plt.bar(data['numVotes'], data['averageRating'])

# Adding title to the plot
plt.title("Bar Chart of Number of Votes vs Average Rating")

# Setting the X and Y labels
plt.xlabel('Number of Votes')
plt.ylabel('Average Rating')

# Display the plot
plt.show()

# %%
# Histogram
import pandas as pd
import matplotlib.pyplot as plt

# Reading the database
data = pd.read_csv("data.csv")

# Histogram of 'averageRating'
plt.hist(data['averageRating'], bins=10, edgecolor='black')

# Adding title to the plot
plt.title("Histogram of Average Rating")

# Labeling the axes
plt.xlabel('Average Rating')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %%
# Line Plot
# Importing packages
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Reading the database
data = pd.read_csv("data.csv")

# Draw lineplot with 'numVotes' on x-axis and 'averageRating' on y-axis
sns.lineplot(x="numVotes", y="averageRating", data=data)

# Setting the title using Matplotlib
plt.title('Votes vs Average Rating Trend')

# Display the plot
plt.show()

# %%
# Pair Plot with Bokeh
# Importing the modules
from bokeh.plotting import figure, output_file, show
from bokeh.palettes import magma
import pandas as pd

# Reading the database
data = pd.read_csv("data.csv")

# Instantiating the figure object
graph = figure(title="Bokeh Scatter Graph: Average Rating vs Number of Votes")

# Choosing a color palette
color = magma(256)

# Plotting the graph using 'numVotes' and 'averageRating'
graph.scatter(data['numVotes'], data['averageRating'], color=color)

# Displaying the plot
show(graph)

# %%
# Importing necessary libraries
import seaborn as sns
import pandas as pd

# Loading your dataset
data = pd.read_csv("data.csv")

# Creating a pair plot with relevant numerical columns
# Select only the numerical columns for the pair plot
# Here we're using averageRating, numVotes, and releaseYear for demonstration
sns.pairplot(data[['averageRating', 'numVotes', 'releaseYear']])

# Display the pair plot
plt.show()

# %%
#EXO 02 SVM
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
# Load the Iris dataset
iris = load_iris()
# Split data into features (X) and target (y)
X = iris.data
y = iris.target
# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Model training (SVM)
svm_model = SVC(kernel='linear', C=1, gamma='scale')
svm_model.fit(X_train, y_train)
# Model evaluation
y_pred = svm_model.predict(X_test)
# Print classification report and confusion matrix
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.92      0.96        13
#            2       0.95      1.00      0.97        19
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
# Confusion Matrix:
# [[13  0  0]
#  [ 0 12  1]
#  [ 0  0 19]]
